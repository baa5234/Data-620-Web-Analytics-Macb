# %%
#Blessing Anoroh
#Date: February 25, 2026 (Due March 1, 2026)
#Data 621 web analytics
# Assignment 4

# %% [markdown]
# For this project, I will use the U.S. House of Representatives cosponsorship dataset available from Cornell University:
# https://www.cs.cornell.edu/~arb/data/house-bills/
#
# This dataset contains bill cosponsorship information for members of the U.S. House of Representatives. In this network, each node represents a legislator, and edges represent cosponsorship relationships. If two members sponsor or cosponsor the same bill, they are connected. This creates a collaboration network that shows how legislators work together.
#
# The dataset can be combined with publicly available information about each legislator, such as political party, state, and other attributes. The most important categorical variable for this project will be political party (Democrat or Republican), which will allow me to compare centrality measures across groups.

# %% [markdown]
# Plan for How to Load Data for Analysis
#
#
# First, I will load the dataset into Python using pandas and networkx. Then, I will use networkx to create a graph where nodes represent legislators and edges represent cosponsorship relationships. I will attach attributes like party affiliation to each node.
#
# Next, I will calculate centrality measures:
#
# Degree centrality (how many connections each member has)
#
# Betweenness centrality (who connects different groups)
#
# Eigenvector centrality (who is connected to other important members)
#
# After calculating these measures, I will compare the average degree centrality between political parties.

# %% [markdown]
# Research Questions
#
# Some questions I want to explore are:
#
# Do members of the majority party have more connections than members of the minority party?
#
# Are there members who act as bridges between parties?
#
# Does having more connections relate to greater influence?

# %% [markdown]
# Possible Outcome
#
# One possible outcome is that members of the majority party may have higher average degree centrality because they work with more colleagues. This could suggest that degree centrality helps predict legislative influence.
#
# Another possibility is that some minority party members who collaborate across party lines may also have high degree centrality. Comparing parties will show whether network position differs between groups and what that means for influence.
